# %% [markdown]
# ## Feature Engineering for the unemployment Rate in Kenya

# %%
import os
import re
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
from itertools import combinations
pd.set_option('mode.use_inf_as_na', True)

# %% [markdown]
# ### Define functions for repeated tasks

# %%
# Function to extract headers from a given file
def extract_headers(file_path):
    try:
        # Read the first sheet of the Excel file
        df = pd.read_excel(file_path)
        
        # Get the column headers
        headers = df.columns.tolist()
        
        return headers
    except Exception as e:
        return []
##########################################


def replace_characters(dataframe):
    # Iterate through the columns and update their names
    for col in dataframe.columns:
        # replace spaces, whitespaces, parenthesis with underscore and remove commas and % signs
        new_col_name = re.sub(r'[\s(),]+', '_', col).strip('_')
        new_col_name = re.sub(r'%', 'Percent', new_col_name)
        
        # Update the column name in the DataFrame
        dataframe.rename(columns={col: new_col_name}, inplace=True)

    # Return a list of the modified column names
    return dataframe.columns

##########################################
# replace dataframe datatype to numeric if it is actually numeric
def convert_to_float_or_pass(input_string):
    try:
        result = float(input_string)
        return result
    except ValueError:
        pass

# create barplots for all columns
# Create separate subplots for each column
def barplots(df):
    nrows=int(len(df.columns)/2)
    fig, axes = plt.subplots(nrows=nrows,ncols=len(df.columns)-nrows, figsize=(15, 5))
    for i, col in enumerate(df.columns):
        sns.barplot(x=df.index, y=col, data=df, ax=axes[i])
        axes[i].set_title(col)
        axes[i].set_xlabel('Year')
        axes[i].set_ylabel('Value')

        plt.tight_layout()
    return plt.show()

# %% [markdown]
# ## Read the data into dataframe(s) and rename the column names for easy readibility

# %%
unemployment_historical=pd.read_excel("/Users/aman/Documents/omdena/Kenya/data/EDA/Final_preprocessing_dataset.xlsx",skiprows=1)
unemployment_historical.columns=replace_characters(unemployment_historical)
unemployment_historical.shape
unemployment_historical.head()
# Out:
#    Year  Unemployment_Rate_Percent  Inflation_Rate  Labour_Force  \
# 0  2000                     0.0313            9.98      12114213
# 1  2001                     0.0307            5.73      12601491
# 2  2002                     0.0309            1.97      13103364
# 3  2003                     0.0304            9.81      13606235
# 4  2004                     0.0300           11.80      14125163
#
#    Nominal_GDP_prices_Ksh_Million  Annual_GDP_growth_Percent  \
# 0                          967838                        0.0
# 1                         1020022                        3.8
# 2                         1035374                        0.5
# 3                         1131783                        2.9
# 4                         1274328                        5.1
#
#    Real_GDP_prices_Ksh_Million  population_growth  Population_total  \
# 0                       982855               2.92          30851606
# 1                      1020111               3.03          31800343
# 2                      1025583               3.03          32779823
# 3                      1055658               2.97          33767122
# 4                      1109338               2.99          34791836
#
#   Urban_population_growth_annual_Percent  \
# 0                                   0.07
# 1                                   1.95
# 2                                   0.67
# 3                                   0.49
# 4                                   5.82
#
#   Adjusted_net_national_income_per_capita_annual_Percent_growth  \
# 0                                              -2.81
# 1                                              -1.09
# 2                                              -2.34
# 3                                              -2.44
# 4                                                2.7
#
#   Adjusted_savings:_education_expenditure_current_US$  \
# 0                                       645127096.87
# 1                                       656047739.08
# 2                                        755517161.8
# 3                                       897571127.36
# 4                                      1011467728.44
#
#    Labor_force_participation_rate_for_ages_15-24_female_Percent_modeled_ILO_estimate  \
# 0                                              50.46
# 1                                              50.03
# 2                                              49.61
# 3                                              49.18
# 4                                              48.76
#
#    Labor_force_participation_rate_for_ages_15-24_male_Percent_modeled_ILO_estimate  \
# 0                                              46.89
# 1                                              46.87
# 2                                              46.84
# 3                                              46.82
# 4                                              46.79
#
#    Unemployment_female_Percent_of_female_labor_force_modeled_ILO_estimate  \
# 0                                               3.37
# 1                                               3.31
# 2                                               3.33
# 3                                               3.28
# 4                                               3.23
#
#    Unemployment_male_Percent_of_male_labor_force_modeled_ILO_estimate  \
# 0                                               2.89
# 1                                               2.84
# 2                                               2.86
# 3                                               2.82
# 4                                               2.77
#
#    Unemployment_total_Percent_of_total_labor_force_modeled_ILO_estimate
# 0                                               3.13
# 1                                               3.07
# 2                                               3.09
# 3                                               3.04
# 4                                               3.00

# %% [markdown]
# ## Check the data types

# %%
unemployment_historical['Year']=pd.to_datetime(unemployment_historical['Year'],format='%Y').dt.year
unemployment_historical.dtypes
unemployment_historical
# Out:
#     Year  Unemployment_Rate_Percent  Inflation_Rate  Labour_Force  \
# 0   2000                     0.0313            9.98      12114213
# 1   2001                     0.0307            5.73      12601491
# 2   2002                     0.0309            1.97      13103364
# 3   2003                     0.0304            9.81      13606235
# 4   2004                     0.0300           11.80      14125163
# 5   2005                     0.0297            9.91      14646884
# 6   2006                     0.0294            6.03      15171370
# 7   2007                     0.0292            4.27      15697007
# 8   2008                     0.0298           15.11      16235546
# 9   2009                     0.0292           10.54      16792371
# 10  2010                     0.0285            4.08      17354366
# 11  2011                     0.0286           14.02      17926485
# 12  2012                     0.0284            9.38      18509902
# 13  2013                     0.0283            5.72      19107609
# 14  2014                     0.0280            6.88      19718332
# 15  2015                     0.0277            6.58      20338656
# 16  2016                     0.0276            6.32      20989035
# 17  2017                     0.0352            7.99      21588086
# 18  2018                     0.0425            4.69      22178699
# 19  2019                     0.0501            5.24      22775099
# 20  2020                     0.0562            5.29      23230574
# 21  2021                     0.0564            6.11      24116304
# 22  2022                     0.0550            7.65      24985164
#
#     Nominal_GDP_prices_Ksh_Million  Annual_GDP_growth_Percent  \
# 0                           967838                        0.0
# 1                          1020022                        3.8
# 2                          1035374                        0.5
# 3                          1131783                        2.9
# 4                          1274328                        5.1
# 5                          1415823                        5.7
# 6                          1622565                        6.5
# 7                          1833511                        6.9
# 8                          2107589                        1.5
# 9                          3275642                        2.7
# 10                         3597630                        8.1
# 11                         4162514                        5.1
# 12                         4767191                        4.6
# 13                         5311322                        3.8
# 14                         6003835                        5.0
# 15                         6884317                        5.0
# 16                         7594064                        4.2
# 17                         8483396                        3.8
# 18                         9340307                        5.6
# 19                        10237727                        5.1
# 20                        10715070                       -0.3
# 21                        12027662                        7.6
# 22                        13368340                        4.8
#
#     Real_GDP_prices_Ksh_Million  population_growth  Population_total  \
# 0                        982855               2.92          30851606
# 1                       1020111               3.03          31800343
# 2                       1025583               3.03          32779823
# 3                       1055658               2.97          33767122
# 4                       1109338               2.99          34791836
# 5                       1172784               2.98          35843010
# 6                       1249470               2.97          36925253
# 7                       1336849               2.97          38036793
# 8                       1357262               2.98          39186895
# 9                       5361462               2.96          40364444
# 10                      5793514               2.82          41517895
# 11                      6090206               2.66          42635144
# 12                      6368448               2.53          43725806
# 13                      6610312               2.41          44792368
# 14                      6942157               2.29          45831863
# 15                      7287024               2.20          46851488
# 16                      7594064               2.20          47894670
# 17                      7885521               2.18          48948137
# 18                      8330891               2.03          49953304
# 19                      8756946               1.98          50951450
# 20                      8733060               2.01          51985780
# 21                      9395942               1.94          53005614
# 22                      9851329               1.91          54027487
#
#    Urban_population_growth_annual_Percent  \
# 0                                    0.07
# 1                                    1.95
# 2                                    0.67
# 3                                    0.49
# 4                                    5.82
# 5                                     8.3
# 6                                   14.29
# 7                                    4.85
# 8                                    2.18
# 9                                   -4.45
# 10                                   6.33
# 11                                   3.82
# 12                                   7.37
# 13                                   4.02
# 14                                   2.82
# 15                                    9.6
# 16                                  17.97
# 17                                   0.88
# 18                                   7.07
# 19                                   4.41
# 20                                   0.54
# 21                                     ..
# 22                                     ..
#
#    Adjusted_net_national_income_per_capita_annual_Percent_growth  \
# 0                                               -2.81
# 1                                               -1.09
# 2                                               -2.34
# 3                                               -2.44
# 4                                                 2.7
# 5                                                5.13
# 6                                               10.94
# 7                                                1.79
# 8                                               -0.82
# 9                                               -7.24
# 10                                               3.38
# 11                                                1.1
# 12                                               4.69
# 13                                               1.54
# 14                                               0.49
# 15                                               7.21
# 16                                               15.4
# 17                                              -1.29
# 18                                               4.91
# 19                                               2.36
# 20                                              -1.46
# 21                                                 ..
# 22                                                 ..
#
#    Adjusted_savings:_education_expenditure_current_US$  \
# 0                                        645127096.87
# 1                                        656047739.08
# 2                                         755517161.8
# 3                                        897571127.36
# 4                                       1011467728.44
# 5                                       1215687557.67
# 6                                        1710161374.1
# 7                                       1972468804.57
# 8                                       2065737290.63
# 9                                       1967168900.61
# 10                                      1944800088.85
# 11                                      2078467401.15
# 12                                      2625885528.04
# 13                                      2844350768.53
# 14                                         3030017914
# 15                                      3077920855.78
# 16                                      3594666339.01
# 17                                      3922081797.18
# 18                                      4422957900.56
# 19                                      4819176837.36
# 20                                      4837661811.85
# 21                                                 ..
# 22                                                 ..
#
#     Labor_force_participation_rate_for_ages_15-24_female_Percent_modeled_ILO_estimate  \
# 0                                               50.46
# 1                                               50.03
# 2                                               49.61
# 3                                               49.18
# 4                                               48.76
# 5                                               48.34
# 6                                               47.91
# 7                                               47.48
# 8                                               47.05
# 9                                               46.62
# 10                                              46.19
# 11                                              45.77
# 12                                              45.35
# 13                                              44.92
# 14                                              44.50
# 15                                              44.07
# 16                                              43.64
# 17                                              43.09
# 18                                              42.54
# 19                                              41.96
# 20                                              41.54
# 21                                              41.61
# 22                                              41.87
#
#     Labor_force_participation_rate_for_ages_15-24_male_Percent_modeled_ILO_estimate  \
# 0                                               46.89
# 1                                               46.87
# 2                                               46.84
# 3                                               46.82
# 4                                               46.79
# 5                                               46.77
# 6                                               46.75
# 7                                               46.72
# 8                                               46.71
# 9                                               46.69
# 10                                              46.67
# 11                                              46.65
# 12                                              46.62
# 13                                              46.60
# 14                                              46.58
# 15                                              46.56
# 16                                              46.56
# 17                                              45.22
# 18                                              43.86
# 19                                              42.46
# 20                                              42.07
# 21                                              41.96
# 22                                              42.65
#
#     Unemployment_female_Percent_of_female_labor_force_modeled_ILO_estimate  \
# 0                                                3.37
# 1                                                3.31
# 2                                                3.33
# 3                                                3.28
# 4                                                3.23
# 5                                                3.20
# 6                                                3.17
# 7                                                3.14
# 8                                                3.19
# 9                                                3.13
# 10                                               3.05
# 11                                               3.06
# 12                                               3.05
# 13                                               3.03
# 14                                               2.99
# 15                                               2.96
# 16                                               2.95
# 17                                               3.72
# 18                                               4.47
# 19                                               5.25
# 20                                               5.78
# 21                                               5.94
# 22                                               5.80
#
#     Unemployment_male_Percent_of_male_labor_force_modeled_ILO_estimate  \
# 0                                                2.89
# 1                                                2.84
# 2                                                2.86
# 3                                                2.82
# 4                                                2.77
# 5                                                2.75
# 6                                                2.73
# 7                                                2.71
# 8                                                2.77
# 9                                                2.72
# 10                                               2.65
# 11                                               2.66
# 12                                               2.65
# 13                                               2.64
# 14                                               2.61
# 15                                               2.60
# 16                                               2.58
# 17                                               3.32
# 18                                               4.03
# 19                                               4.77
# 20                                               5.45
# 21                                               5.35
# 22                                               5.21
#
#     Unemployment_total_Percent_of_total_labor_force_modeled_ILO_estimate
# 0                                                3.13
# 1                                                3.07
# 2                                                3.09
# 3                                                3.04
# 4                                                3.00
# 5                                                2.97
# 6                                                2.94
# 7                                                2.92
# 8                                                2.98
# 9                                                2.92
# 10                                               2.85
# 11                                               2.86
# 12                                               2.84
# 13                                               2.83
# 14                                               2.80
# 15                                               2.77
# 16                                               2.76
# 17                                               3.52
# 18                                               4.25
# 19                                               5.01
# 20                                               5.62
# 21                                               5.64
# 22                                               5.50

# %% [markdown]
# ## Convert the Year column into index and convert the series into time series

# %%
unemployment_historical.index=pd.to_datetime(unemployment_historical['Year'],format='%Y').dt.year
unemployment_historical=unemployment_historical.drop(['Year','Nominal_GDP_prices_Ksh_Million','Unemployment_Rate_Percent','Unemployment_male_Percent_of_male_labor_force_modeled_ILO_estimate','Unemployment_female_Percent_of_female_labor_force_modeled_ILO_estimate'],axis=1)
unemployment_historical.head()
# Out:
#       Inflation_Rate  Labour_Force  Annual_GDP_growth_Percent  \
# Year
# 2000            9.98      12114213                        0.0
# 2001            5.73      12601491                        3.8
# 2002            1.97      13103364                        0.5
# 2003            9.81      13606235                        2.9
# 2004           11.80      14125163                        5.1
#
#       Real_GDP_prices_Ksh_Million  population_growth  Population_total  \
# Year
# 2000                       982855               2.92          30851606
# 2001                      1020111               3.03          31800343
# 2002                      1025583               3.03          32779823
# 2003                      1055658               2.97          33767122
# 2004                      1109338               2.99          34791836
#
#      Urban_population_growth_annual_Percent  \
# Year
# 2000                                   0.07
# 2001                                   1.95
# 2002                                   0.67
# 2003                                   0.49
# 2004                                   5.82
#
#      Adjusted_net_national_income_per_capita_annual_Percent_growth  \
# Year
# 2000                                              -2.81
# 2001                                              -1.09
# 2002                                              -2.34
# 2003                                              -2.44
# 2004                                                2.7
#
#      Adjusted_savings:_education_expenditure_current_US$  \
# Year
# 2000                                       645127096.87
# 2001                                       656047739.08
# 2002                                        755517161.8
# 2003                                       897571127.36
# 2004                                      1011467728.44
#
#       Labor_force_participation_rate_for_ages_15-24_female_Percent_modeled_ILO_estimate  \
# Year
# 2000                                              50.46
# 2001                                              50.03
# 2002                                              49.61
# 2003                                              49.18
# 2004                                              48.76
#
#       Labor_force_participation_rate_for_ages_15-24_male_Percent_modeled_ILO_estimate  \
# Year
# 2000                                              46.89
# 2001                                              46.87
# 2002                                              46.84
# 2003                                              46.82
# 2004                                              46.79
#
#       Unemployment_total_Percent_of_total_labor_force_modeled_ILO_estimate
# Year
# 2000                                               3.13
# 2001                                               3.07
# 2002                                               3.09
# 2003                                               3.04
# 2004                                               3.00

# %% [markdown]
# ## Replace data types to numeric values

# %%
# replace all column types to numeric if they are numeric indeed
for col in unemployment_historical.columns:
    if unemployment_historical[col].dtype == 'object':
        unemployment_historical[col] = unemployment_historical[col].apply(convert_to_float_or_pass)

# %%
# Create a dictionary to map old column names to new, simpler names for all columns
column_name_mapping = {
    'Inflation_Rate': 'Inflation',
    'Labour_Force': 'Labor',
    'Nominal_GDP_prices_Ksh_Million': 'Nominal_GDP_Ksh',
    'Annual_GDP_growth_Percent': 'GDP_Growth',
    'Real_GDP_prices_Ksh_Million': 'Real_GDP_Ksh',
    'population_growth': 'Population_Growth',
    'Population_total': 'Total_Population',
    'Urban_population_growth_annual_Percent': 'Urban_Population_Growth',
    'Adjusted_net_national_income_per_capita_annual_Percent_growth': 'Income_Per_Capita_Growth',
    'Adjusted_savings:_education_expenditure_current_US$': 'Education_Expenditure_usd',
    'Labor_force_participation_rate_for_ages_15-24_female_Percent_modeled_ILO_estimate': 'Female_Labor_Participation',
    'Labor_force_participation_rate_for_ages_15-24_male_Percent_modeled_ILO_estimate': 'Male_Labor_Participation',
    'Unemployment_female_Percent_of_female_labor_force_modeled_ILO_estimate': 'Female_Unemployment',
    'Unemployment_male_Percent_of_male_labor_force_modeled_ILO_estimate': 'Male_Unemployment',
    'Unemployment_total_Percent_of_total_labor_force_modeled_ILO_estimate': 'Total_Unemployment'
}

# Rename the columns in the DataFrame
unemployment_df = unemployment_historical.rename(columns=column_name_mapping)

# %% [markdown]
# ## convert the usd expenditure to Ksh since all the other columns represent ksh

# %%
unemployment_df.fillna(unemployment_df.median(),inplace=True)
usd_to_Ksh=pd.read_excel("/Users/aman/Downloads/Dollar_Rate.xlsx")
usd_to_Ksh.index=usd_to_Ksh["YEAR"]
unemployment_df["Education_Expenditure_Ksh"]=unemployment_df["Education_Expenditure_usd"]*usd_to_Ksh["DOLLAR RATE ANNUALLY"]
unemployment_df.drop(["Education_Expenditure_usd"],axis=1,inplace=True)
unemployment_df["Dollar_Rate"]=usd_to_Ksh["DOLLAR RATE ANNUALLY"]

# %%
unemployment_df.describe().T
# Out:
#                             count          mean           std           min  \
# Inflation                    23.0  7.613043e+00  3.251344e+00  1.970000e+00
# Labor                        23.0  1.812661e+07  3.912670e+06  1.211421e+07
# GDP_Growth                   23.0  4.260870e+00  2.246156e+00 -3.000000e-01
# Real_GDP_Ksh                 23.0  5.013512e+06  3.346256e+06  9.828550e+05
# Population_Growth            23.0  2.563478e+00  4.305030e-01  1.910000e+00
# Total_Population             23.0  4.245514e+07  7.260731e+06  3.085161e+07
# Urban_Population_Growth      23.0  4.653913e+00  4.825958e+00 -4.450000e+00
# Income_Per_Capita_Growth     23.0  1.966522e+00  4.794671e+00 -7.240000e+00
# Female_Labor_Participation   23.0  4.576043e+01  2.896549e+00  4.154000e+01
# Male_Labor_Participation     23.0  4.575261e+01  1.759202e+00  4.196000e+01
# Total_Unemployment           23.0  3.448261e+00  9.915949e-01  2.760000e+00
# Education_Expenditure_Ksh    23.0  2.187303e+11  1.432394e+11  4.914291e+10
# Dollar_Rate                  23.0  8.813952e+01  1.411275e+01  6.746677e+01
#
#                                      25%           50%           75%  \
# Inflation                   5.505000e+00  6.580000e+00  9.860000e+00
# Labor                       1.490913e+07  1.792648e+07  2.128856e+07
# GDP_Growth                  3.350000e+00  4.800000e+00  5.350000e+00
# Real_GDP_Ksh                1.211127e+06  6.090206e+06  7.739792e+06
# Population_Growth           2.190000e+00  2.660000e+00  2.970000e+00
# Total_Population            3.638413e+07  4.263514e+07  4.842140e+07
# Urban_Population_Growth     1.415000e+00  4.020000e+00  6.700000e+00
# Income_Per_Capita_Growth   -1.190000e+00  1.540000e+00  4.035000e+00
# Female_Labor_Participation  4.336500e+01  4.577000e+01  4.812500e+01
# Male_Labor_Participation    4.589000e+01  4.665000e+01  4.676000e+01
# Total_Unemployment          2.855000e+00  2.980000e+00  3.325000e+00
# Education_Expenditure_Ksh   1.076227e+11  1.847061e+11  2.848197e+11
# Dollar_Rate                 7.795137e+01  8.452290e+01  1.013982e+02
#
#                                      max
# Inflation                   1.511000e+01
# Labor                       2.498516e+07
# GDP_Growth                  8.100000e+00
# Real_GDP_Ksh                9.851329e+06
# Population_Growth           3.030000e+00
# Total_Population            5.402749e+07
# Urban_Population_Growth     1.797000e+01
# Income_Per_Capita_Growth    1.540000e+01
# Female_Labor_Participation  5.046000e+01
# Male_Labor_Participation    4.689000e+01
# Total_Unemployment          5.640000e+00
# Education_Expenditure_Ksh   5.150544e+11
# Dollar_Rate                 1.178443e+02

# %% [markdown]
# ## Check the distribution of the data

# %%
unemployment_df.hist(figsize=(25,15))
# Out:
# array([[<Axes: title={'center': 'Inflation'}>,
#         <Axes: title={'center': 'Labor'}>,
#         <Axes: title={'center': 'GDP_Growth'}>,
#         <Axes: title={'center': 'Real_GDP_Ksh'}>],
#        [<Axes: title={'center': 'Population_Growth'}>,
#         <Axes: title={'center': 'Total_Population'}>,
#         <Axes: title={'center': 'Urban_Population_Growth'}>,
#         <Axes: title={'center': 'Income_Per_Capita_Growth'}>],
#        [<Axes: title={'center': 'Female_Labor_Participation'}>,
#         <Axes: title={'center': 'Male_Labor_Participation'}>,
#         <Axes: title={'center': 'Total_Unemployment'}>,
#         <Axes: title={'center': 'Education_Expenditure_Ksh'}>],
#        [<Axes: title={'center': 'Dollar_Rate'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
# Calculate the correlations between features and the target
correlations = unemployment_df.corr()['Total_Unemployment'].sort_values(ascending=True)

# Create a barplot to visualize correlations
plt.figure(figsize=(8, 6))
sns.barplot(x=correlations, y=correlations.index, orient='h',color="grey")
plt.title('Correlations with Target')
plt.xlabel('Correlation')
plt.ylabel('Feature')
plt.grid(axis='x')

# Annotate the correlation values on the bars
for i, corr in enumerate(correlations):
    plt.text(corr, i, f'{corr:.2f}', va='center', fontsize=10, color='black')
plt.grid(axis='x')

# %% [markdown]
# ## Scale the data to calculate the correlations

# %%
scaling=MinMaxScaler()
scaled=scaling.fit_transform(unemployment_df)
scaled_df= pd.DataFrame(scaled, columns=unemployment_df.columns)
scaled_df.index=unemployment_df.index

scaled_df.head()
# Out:
#       Inflation     Labor  GDP_Growth  Real_GDP_Ksh  Population_Growth  \
# Year
# 2000   0.609589  0.000000    0.035714      0.000000           0.901786
# 2001   0.286149  0.037859    0.488095      0.004201           1.000000
# 2002   0.000000  0.076851    0.095238      0.004818           1.000000
# 2003   0.596651  0.115922    0.380952      0.008209           0.946429
# 2004   0.748097  0.156239    0.642857      0.014262           0.964286
#
#       Total_Population  Urban_Population_Growth  Income_Per_Capita_Growth  \
# Year
# 2000          0.000000                 0.201606                  0.195671
# 2001          0.040936                 0.285459                  0.271643
# 2002          0.083199                 0.228368                  0.216431
# 2003          0.125800                 0.220339                  0.212014
# 2004          0.170014                 0.458073                  0.439046
#
#       Female_Labor_Participation  Male_Labor_Participation  \
# Year
# 2000                    1.000000                  1.000000
# 2001                    0.951794                  0.995943
# 2002                    0.904709                  0.989858
# 2003                    0.856502                  0.985801
# 2004                    0.809417                  0.979716
#
#       Total_Unemployment  Education_Expenditure_Ksh  Dollar_Rate
# Year
# 2000            0.128472                   0.000000     0.172870
# 2001            0.107639                   0.005148     0.220265
# 2002            0.114583                   0.022222     0.223956
# 2003            0.097222                   0.056633     0.331130
# 2004            0.083333                   0.069610     0.261691

# %%
# Calculate the correlations between features and the target
correlations_new = scaled_df.corr()['Total_Unemployment'].sort_values(ascending=True)

# Create a barplot to visualize correlations
plt.figure(figsize=(8, 6))
sns.barplot(x=correlations_new, y=correlations_new.index, orient='h',color="lightgrey")
plt.title('Correlations of the Scaled data with Target')
plt.xlabel('Correlation')
plt.ylabel('Feature')
plt.grid(axis='x')

# Annotate the correlation values on the bars
for i, corr in enumerate(correlations_new):
    plt.text(corr, i, f'{corr:.2f}', va='center', fontsize=10, color='black')
plt.grid(axis='x')

# %% [markdown]
# ###  Comparing (above) the correations of the scaled data to the correlations of the original data, we realize that they are exactly the same. This validates our scaling method!

# %% [markdown]
# # Calculate ratio of each field with another to compare against the unemployment rate with a condition given that the correlation with the unemployment rate is > 0.5

# %%
# Get columns without the last
cols_without_last = scaled_df.drop(['Total_Unemployment'],axis=1).columns

# Create unique pairs without the last column
unique_pairs = list(combinations(cols_without_last, 2))

# Calculate ratios and check correlation with the last column
ratios = pd.DataFrame()
for col1, col2 in unique_pairs:
    ratio_name = f'{col1}_{col2}_Ratio'
    ratio = scaled_df[col1] / scaled_df[col2]

    correlation_with_last = ratio.corr(unemployment_df['Total_Unemployment'])

    if (correlation_with_last > 0.5) or (correlation_with_last < -0.5):
        ratios[ratio_name] = ratio



ratios = ratios[sorted(ratios.columns)]
#remove nan values by filling up with median
ratios.fillna(ratios.median(),inplace=True)
ratios.head()
# Out:
#       GDP_Growth_Female_Labor_Participation_Ratio  \
# Year
# 2000                                     0.035714
# 2001                                     0.512816
# 2002                                     0.105269
# 2003                                     0.444777
# 2004                                     0.794222
#
#       GDP_Growth_Male_Labor_Participation_Ratio  \
# Year
# 2000                                   0.035714
# 2001                                   0.490083
# 2002                                   0.096214
# 2003                                   0.386439
# 2004                                   0.656167
#
#       GDP_Growth_Population_Growth_Ratio  \
# Year
# 2000                            0.039604
# 2001                            0.488095
# 2002                            0.095238
# 2003                            0.402516
# 2004                            0.666667
#
#       Income_Per_Capita_Growth_Female_Labor_Participation_Ratio  \
# Year
# 2000                                           0.195671
# 2001                                           0.285401
# 2002                                           0.239227
# 2003                                           0.247535
# 2004                                           0.542422
#
#       Income_Per_Capita_Growth_Male_Labor_Participation_Ratio  \
# Year
# 2000                                           0.195671
# 2001                                           0.272750
# 2002                                           0.218649
# 2003                                           0.215068
# 2004                                           0.448136
#
#       Inflation_Female_Labor_Participation_Ratio  \
# Year
# 2000                                    0.609589
# 2001                                    0.300642
# 2002                                    0.000000
# 2003                                    0.696614
# 2004                                    0.924242
#
#       Inflation_Male_Labor_Participation_Ratio  \
# Year
# 2000                                  0.609589
# 2001                                  0.287315
# 2002                                  0.000000
# 2003                                  0.605245
# 2004                                  0.763586
#
#       Inflation_Population_Growth_Ratio  \
# Year
# 2000                           0.675980
# 2001                           0.286149
# 2002                           0.000000
# 2003                           0.630424
# 2004                           0.775805
#
#       Labor_Female_Labor_Participation_Ratio  \
# Year
# 2000                                0.000000
# 2001                                0.039776
# 2002                                0.084946
# 2003                                0.135343
# 2004                                0.193027
#
#       Labor_Income_Per_Capita_Growth_Ratio  ...  \
# Year                                        ...
# 2000                              0.000000  ...
# 2001                              0.139369  ...
# 2002                              0.355085  ...
# 2003                              0.546764  ...
# 2004                              0.355861  ...
#
#       Real_GDP_Ksh_Male_Labor_Participation_Ratio  \
# Year
# 2000                                     0.000000
# 2001                                     0.004218
# 2002                                     0.004867
# 2003                                     0.008327
# 2004                                     0.014557
#
#       Real_GDP_Ksh_Population_Growth_Ratio  \
# Year
# 2000                              0.000000
# 2001                              0.004201
# 2002                              0.004818
# 2003                              0.008674
# 2004                              0.014790
#
#       Real_GDP_Ksh_Urban_Population_Growth_Ratio  \
# Year
# 2000                                    0.000000
# 2001                                    0.014716
# 2002                                    0.021097
# 2003                                    0.037257
# 2004                                    0.031135
#
#       Total_Population_Female_Labor_Participation_Ratio  \
# Year
# 2000                                           0.000000
# 2001                                           0.043010
# 2002                                           0.091963
# 2003                                           0.146876
# 2004                                           0.210045
#
#       Total_Population_Income_Per_Capita_Growth_Ratio  \
# Year
# 2000                                         0.000000
# 2001                                         0.150699
# 2002                                         0.384415
# 2003                                         0.593355
# 2004                                         0.387236
#
#       Total_Population_Male_Labor_Participation_Ratio  \
# Year
# 2000                                         0.000000
# 2001                                         0.041103
# 2002                                         0.084052
# 2003                                         0.127612
# 2004                                         0.173534
#
#       Total_Population_Urban_Population_Growth_Ratio  \
# Year
# 2000                                        0.000000
# 2001                                        0.143405
# 2002                                        0.364322
# 2003                                        0.570937
# 2004                                        0.371151
#
#       Urban_Population_Growth_Female_Labor_Participation_Ratio  \
# Year
# 2000                                           0.201606
# 2001                                           0.299917
# 2002                                           0.252421
# 2003                                           0.257254
# 2004                                           0.565930
#
#       Urban_Population_Growth_Income_Per_Capita_Growth_Ratio  \
# Year
# 2000                                           1.030328
# 2001                                           1.050862
# 2002                                           1.055151
# 2003                                           1.039266
# 2004                                           1.043338
#
#       Urban_Population_Growth_Male_Labor_Participation_Ratio
# Year
# 2000                                           0.201606
# 2001                                           0.286622
# 2002                                           0.230707
# 2003                                           0.223513
# 2004                                           0.467557
#
# [5 rows x 26 columns]

# %%
#ratios["IncomePerCapita_TotalPop_Growth_Ratio"]=scaled_df["Income_Per_Capita_Growth"]/scaled_df["Population_Growth"]

# %%
#ratios.fillna(ratios.median(),inplace=True)
ratios["Total_Unemployment"]=unemployment_df["Total_Unemployment"]
ratios.corr()["Total_Unemployment"]
# Out:
# Total_Unemployment                                        1.000000
# Labor_Total_Population_Ratio                              0.823253
# Urban_Population_Growth_Income_Per_Capita_Growth_Ratio   -0.607461
# Name: Total_Unemployment, dtype: float64

# %% [markdown]
# # Correlations for all the ratios

# %%
# Calculate the correlations between features and the target
correlations_ratios = ratios.corr()['Total_Unemployment'].sort_values(ascending=True)

# Create a barplot to visualize correlations
plt.figure(figsize=(10, 8))
sns.barplot(x=correlations_ratios, y=correlations_ratios.index, orient='h',color="lightgrey")
plt.title('Initial Ratios Correlations with Target ')
plt.xlabel('Correlation')
plt.ylabel('Feature')
plt.grid(axis='x')

# Annotate the correlation values on the bars
for i, corr in enumerate(correlations_ratios):
    plt.text(corr, i, f'{corr:.2f}', va='center', fontsize=10, color='black')
plt.grid(axis='x')

# %%
ratios_final=ratios[["Total_Unemployment","Labor_Total_Population_Ratio","Urban_Population_Growth_Income_Per_Capita_Growth_Ratio"]]

# %% [markdown]
# ### From the above correlation plot, we will remove all the factors which try to divide percentages by the actual numbers, because they would not reveal a meaninful correlation even if mathematically it is a high number. Moreover, if an original feature shows a stronger correlation or anti-correlation as compared to either of these ratios, we kept the original feature instead. Using this intuition, we decide to only consider "Labor_Total_Population_Ratio" and "Urban_Population_Growth_Income_Per_Capita_Growth_Ratio" from above.

# %%
#ratios.drop("Urban_Population_Growth_Income_Per_Capita_Growth_Ratio",axis=1,inplace=True)
ratios_final.head()
# Calculate the correlations between features and the target
correlations_ratios = ratios_final.corr()['Total_Unemployment'].sort_values(ascending=True)

# Create a barplot to visualize correlations
plt.figure(figsize=(10, 8))
sns.barplot(x=correlations_ratios, y=correlations_ratios.index, orient='h',color="lightgrey")
plt.title('Final Ratios Correlations with Target ')
plt.xlabel('Correlation')
plt.ylabel('Feature')
plt.grid(axis='x')

# Annotate the correlation values on the bars
for i, corr in enumerate(correlations_ratios):
    plt.text(corr, i, f'{corr:.2f}', va='center', fontsize=10, color='black')
plt.grid(axis='x')

# %% [markdown]
# # Create the final data set based on the following findings:
# - Male and female labor force participation are strongly anticorrelated
# -  Labor to total population ratio is better than these two factors alone
# - Plus all the original features in

# %%
unemployment_final=unemployment_df[['Real_GDP_Ksh','Population_Growth','Female_Labor_Participation','Male_Labor_Participation','Education_Expenditure_Ksh','Inflation','Dollar_Rate']]
#scaled_final=scaled_df[['Real_GDP_Ksh','Population_Growth','Female_Labor_Participation','Male_Labor_Participation','Education_Expenditure_Ksh','Total_Unemployment']]

# %% [markdown]
# ## Create the final dataset:
# - with the original data and ratios

# %%
#ratios_scaled_final=pd.concat([scaled_final,ratios_final],axis=1)
ratios_original_final=pd.concat([unemployment_final,ratios_final],axis=1)
#ratios_scaled_final.to_csv("Scaled_data_and_Ratios.csv")
ratios_original_final.to_csv("Feature_Engineered_Dataset.csv")

# %%
ratios_original_final
# Out:
#       Real_GDP_Ksh  Population_Growth  Female_Labor_Participation  \
# Year
# 2000        982855               2.92                       50.46
# 2001       1020111               3.03                       50.03
# 2002       1025583               3.03                       49.61
# 2003       1055658               2.97                       49.18
# 2004       1109338               2.99                       48.76
# 2005       1172784               2.98                       48.34
# 2006       1249470               2.97                       47.91
# 2007       1336849               2.97                       47.48
# 2008       1357262               2.98                       47.05
# 2009       5361462               2.96                       46.62
# 2010       5793514               2.82                       46.19
# 2011       6090206               2.66                       45.77
# 2012       6368448               2.53                       45.35
# 2013       6610312               2.41                       44.92
# 2014       6942157               2.29                       44.50
# 2015       7287024               2.20                       44.07
# 2016       7594064               2.20                       43.64
# 2017       7885521               2.18                       43.09
# 2018       8330891               2.03                       42.54
# 2019       8756946               1.98                       41.96
# 2020       8733060               2.01                       41.54
# 2021       9395942               1.94                       41.61
# 2022       9851329               1.91                       41.87
#
#       Male_Labor_Participation  Education_Expenditure_Ksh  Inflation  \
# Year
# 2000                     46.89               4.914291e+10       9.98
# 2001                     46.87               5.154121e+10       5.73
# 2002                     46.84               5.949633e+10       1.97
# 2003                     46.82               7.552908e+10       9.81
# 2004                     46.79               8.157499e+10      11.80
# 2005                     46.77               9.186504e+10       9.91
# 2006                     46.75               1.233804e+11       6.03
# 2007                     46.72               1.330761e+11       4.27
# 2008                     46.71               1.425422e+11      15.11
# 2009                     46.69               1.521399e+11      10.54
# 2010                     46.67               1.541472e+11       4.08
# 2011                     46.65               1.847061e+11      14.02
# 2012                     46.62               2.219475e+11       9.38
# 2013                     46.60               2.449723e+11       5.72
# 2014                     46.58               2.664100e+11       6.88
# 2015                     46.56               3.032294e+11       6.58
# 2016                     46.56               3.648504e+11       6.32
# 2017                     45.22               4.055902e+11       7.99
# 2018                     43.86               4.480395e+11       4.69
# 2019                     42.46               4.916173e+11       5.24
# 2020                     42.07               5.150544e+11       5.29
# 2021                     41.96               2.265101e+11       6.11
# 2022                     42.65               2.434354e+11       7.65
#
#       Dollar_Rate  Total_Unemployment  Labor_Total_Population_Ratio  \
# Year
# 2000    76.175542                3.13                      0.920229
# 2001    78.563195                3.07                      0.924819
# 2002    78.749142                3.09                      0.923703
# 2003    84.148300                3.04                      0.921479
# 2004    80.650112                3.00                      0.918978
# 2005    75.566327                2.97                      0.913654
# 2006    72.145463                2.94                      0.906346
# 2007    67.466765                2.92                      0.897862
# 2008    69.003071                2.98                      0.890313
# 2009    77.339537                2.92                      0.885504
# 2010    79.261211                2.85                      0.884619
# 2011    88.866501                2.86                      0.888169
# 2012    84.522899                2.84                      0.894525
# 2013    86.125919                2.83                      0.903290
# 2014    87.923579                2.80                      0.914019
# 2015    98.517604                2.77                      0.925583
# 2016   101.497717                2.76                      0.937643
# 2017   103.411962                3.52                      0.942666
# 2018   101.298608                4.25                      0.948736
# 2019   102.012711                5.01                      0.955050
# 2020   106.467626                5.62                      0.947116
# 2021   109.650950                5.64                      0.975507
# 2022   117.844315                5.50                      1.000000
#
#       Urban_Population_Growth_Income_Per_Capita_Growth_Ratio
# Year
# 2000                                           1.030328
# 2001                                           1.050862
# 2002                                           1.055151
# 2003                                           1.039266
# 2004                                           1.043338
# 2005                                           1.040834
# 2006                                           1.040918
# 2007                                           1.040006
# 2008                                           1.042844
# 2009                                           1.000919
# 2010                                           1.025026
# 2011                                           1.001337
# 2012                                           1.000502
# 2013                                           0.974159
# 2014                                           0.949720
# 2015                                           0.981859
# 2016                                           1.000000
# 2017                                           0.904588
# 2018                                           0.957452
# 2019                                           0.931973
# 2020                                           0.871793
# 2021                                           0.974159
# 2022                                           0.974159

# %%
# Calculate the correlations between features and the target
correlations_scaled = ratios_original_final.corr()['Total_Unemployment'].sort_values(ascending=True)

# Create a barplot to visualize correlations
plt.figure(figsize=(12, 10))
sns.barplot(x=correlations_scaled, y=correlations_scaled.index, orient='h',color="lightgrey")
plt.title('Final Features Correlations with the target ')
plt.xlabel('Correlation')
plt.ylabel('Feature')
plt.grid(axis='x')

# Annotate the correlation values on the bars
for i, corr in enumerate(correlations_scaled):
    plt.text(corr, i, f'{corr:.2f}', va='center', fontsize=10, color='black')
plt.grid(axis='x')

# %%
##Seasonality (bonus)
series = pd.Series(unemployment_df['Total_Unemployment'])
results = seasonal_decompose(series, model='additive',period=2)
results.plot()

# %% [markdown]
# ## This is all Folks!!
